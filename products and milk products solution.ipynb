# %%
import pandas as pd
import numpy as np


mp = pd.read_csv('milk_production.csv')
mp.head()
# Out:
#   Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 0    State     Andhra Pradesh            3102.0            3377.0
# 1    State  Arunachal Pradesh              28.0              22.0
# 2    State              Assam             666.0             658.0
# 3    State              Bihar            3561.0            3661.0
# 4    State       Chhattisgarh             644.0             701.0
#
#    Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  Boffalo Milk-2010-11  \
# 0            3799.0              3079              3369                8101.0
# 1              43.0                46                50                   NaN
# 2             677.0               685               703                 101.0
# 3            3986.0              4318              4881                2798.0
# 4             788.0               824               919                 343.0
#
#    Boffalo Milk-2011-12  Boffalo Milk-2013-14  Boffalo Milk-2014-15  \
# ...

# %%
# Which state has produced max milk in year 2013-14?

mp['tot 13-14'] = mp.iloc[:,4]+mp.iloc[:,9]+mp.iloc[:,14]
mp[mp['tot 13-14']==mp['tot 13-14'].max()]
# Out:
#    Category State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 26    State  Uttar Pradesh            5342.0            5837.0
#
#     Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  \
# 26            6142.0              6387              8243
#
#     Boffalo Milk-2010-11  Boffalo Milk-2011-12  Boffalo Milk-2013-14  \
# 26               14496.0               15549.0               16805.0
#
#     Boffalo Milk-2014-15  Boffalo Milk-2015-16  Goat Milk-2010-11  \
# 26                 17524                 16865             1193.0
#
#     Goat Milk-2011-12  Goat Milk-2013-14  Goat Milk-2014-15  \
# 26             1171.0             1248.0               1288
#
#     Goat Milk-2015-16  tot 13-14
# 26               1279    24195.0

# %%
# List top 5 milk producing states in each year from 2010 to 2015

mp['tot 10-11'] = mp.iloc[:,2]+mp.iloc[:,7]+mp.iloc[:,12]
mp['tot 11-12'] = mp.iloc[:,3]+mp.iloc[:,8]+mp.iloc[:,13]
mp['tot 14-15'] = mp.iloc[:,5]+mp.iloc[:,10]+mp.iloc[:,15]
print(mp[mp['tot 10-11']==mp['tot 10-11'].max()],'\n',mp[mp['tot 11-12']==mp['tot 11-12'].max()],'\n',mp[mp['tot 13-14']==mp['tot 13-14'].max()],'\n',mp[mp['tot 13-14']==mp['tot 13-14'].max()])
# Out:
#    Category State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 26    State  Uttar Pradesh            5342.0            5837.0
#
#     Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  \
# 26            6142.0              6387              8243
#
#     Boffalo Milk-2010-11  Boffalo Milk-2011-12  Boffalo Milk-2013-14  ...  \
# 26               14496.0               15549.0               16805.0  ...
#
#     Boffalo Milk-2015-16  Goat Milk-2010-11  Goat Milk-2011-12  \
# 26                 16865             1193.0             1171.0
#
#     Goat Milk-2013-14  Goat Milk-2014-15  Goat Milk-2015-16  tot 13-14  \
# 26             1248.0               1288               1279    24195.0
#
#     tot 10-11  tot 11-12  tot 14-15
# 26    21031.0    22557.0      25199
#
# [1 rows x 21 columns]
#     Category State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 26    State  Uttar Pradesh            5342.0            5837.0
#
# ...

# %%
# Calculate average milk production by cow, buffalo and goat in each year for selected state.
st = input('Enter state\n')
r = mp[[mp['Category'] == 'State'] and mp['State/ UT Name']==st]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# ...

# %%
p = pd.read_csv('products.csv')

# %%
p.head()
# Out:
#    Year       Product line  Product type              Product  \
# 0  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#   Order method type Retailer country    Revenue  Planned revenue  \
# 0         Telephone    United States  315044.33        437477.15
# 1         Telephone           Canada   13444.68         14313.48
# 2         Telephone           Mexico        NaN              NaN
# 3         Telephone           Brazil        NaN              NaN
# 4         Telephone            Japan  181120.24        235236.64
#
#    Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 0     158371.76   66385.0   2.552857        6.59     156672.57
# 1       6298.80    2172.0   2.900000        6.59       7145.88
# ...

# %%
# List all the products
p['Product'].unique()
# Out:
# array(['TrailChef Water Bag', 'TrailChef Canteen',
#        'TrailChef Kitchen Kit', 'TrailChef Cup', 'TrailChef Cook Set',
#        'TrailChef Deluxe Cook Set', 'TrailChef Single Flame',
#        'TrailChef Double Flame', 'TrailChef Kettle', 'TrailChef Utensils',
#        'Star Lite', 'Star Dome', 'Star Gazer 2', 'Star Gazer 3',
#        'Star Gazer 6', 'Star Peg', 'Hibernator Lite', 'Hibernator',
#        'Hibernator Extreme', 'Hibernator Self - Inflating Mat',
#        'Hibernator Pad', 'Hibernator Pillow', 'Hibernator Camp Cot',
#        'Canyon Mule Climber Backpack', 'Canyon Mule Weekender Backpack',
#        'Canyon Mule Journey Backpack', 'Canyon Mule Extreme Backpack',
#        'Canyon Mule Cooler', 'Canyon Mule Carryall', 'Firefly Lite',
#        'Firefly Mapreader', 'Firefly 2', 'Firefly 4', 'Firefly Extreme',
#        'Firefly Multi-light', 'EverGlow Single', 'EverGlow Double',
#        'EverGlow Kerosene', 'EverGlow Butane', 'EverGlow Lamp',
# ...

# %%
# List all country names

p['Retailer country'].unique()
# Out:
# array(['United States', 'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea',
#        'China', 'Singapore', 'Australia', 'Netherlands', 'Sweden',
#        'Finland', 'Denmark', 'France', 'Germany', 'United Kingdom',
#        'Belgium', 'Switzerland', 'Austria', 'Italy', 'Spain'],
#       dtype=object)

# %%
# List all order methods
p['Order method type'].unique()
# Out:
# array(['Telephone', 'Sales visit', 'Web', 'Special', 'Mail', 'E-mail',
#        'Fax'], dtype=object)

# %%
# List the product which is able to sell maximum numbers in United States

p[p['Quantity'] == p[p['Retailer country']=='United States']['Quantity'].max()]
# Out:
#        Year          Product line Product type Product Order method type  \
# 52227  2006  Personal Accessories      Eyewear    Zone               Web
#
#       Retailer country     Revenue  Planned revenue  Product cost  Quantity  \
# 52227    United States  10054289.0       10054289.0    6756852.78  313628.0
#
#        Unit cost  Unit price  Gross profit  Unit sale price
# 52227  21.661547   32.235823    3297436.22        32.235823

# %%
# Find the order method type which is able to sell more number of products in Germany

p[p['Quantity'] == p[p['Retailer country']=='Germany']['Quantity'].max()].loc[:,['Order method type']]
# Out:
#       Order method type
# 31073               Web

# %%
# List the top 5 products which has more gross profit in Australia
p[p['Retailer country']=='Australia'].sort_values(by='Gross profit', ascending = False)
# Out:
#        Year              Product line   Product type  \
# 58850  2006            Golf Equipment          Woods
# 80018  2007            Golf Equipment          Woods
# 43856  2006         Camping Equipment          Tents
# 58409  2006            Golf Equipment          Irons
# 79577  2007            Golf Equipment          Irons
# 44150  2006         Camping Equipment          Tents
# 65024  2007         Camping Equipment          Tents
# 59144  2006            Golf Equipment          Woods
# 80312  2007            Golf Equipment          Woods
# 49295  2006      Personal Accessories        Watches
# 44003  2006         Camping Equipment          Tents
# 45032  2006         Camping Equipment  Sleeping Bags
# 80165  2007            Golf Equipment          Woods
# 72962  2007      Personal Accessories        Eyewear
# 45914  2006         Camping Equipment          Packs
# 58997  2006            Golf Equipment          Woods
# 51941  2006      Personal Accessories        Eyewear
# ...

# %%
# Which order method is more popular (based on Quantity) world wide?
p[p['Quantity']==p['Quantity'].max()]['Order method type']
# Out:
# 52227    Web
# Name: Order method type, dtype: object

# %%
# Show the percentage of order methods for ‘Flicker Lantern’ in Denmark.
p[p['Product']=='Flicker Lantern' and p['Retailer country'] == 'Denmark']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-47eddbaa945f> in <module>
#       1 # Show the percentage of order methods for ‘Flicker Lantern’ in Denmark.
# ----> 2 p[p['Product']=='Flicker Lantern' and p['Retailer country'] == 'Denmark']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
